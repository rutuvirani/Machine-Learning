# %%
import numpy as np
import matplotlib.pyplot as plt

m = 2.5          # Slope
b = 1.0          # Intercept
n = 100          # Number of data points
noise_level = 20  # Noise level (adjustable)

# Generate x-values (independent variable)
x = np.random.rand(n) * 100  # Random x values between 0 and 100

# Calculate y-values based on the linear relationship with added noise we add noice to make more real data
y = m * x + b + np.random.randn(n) * noise_level  # y = mx + b + noise, w/o noise it will be line

plt.scatter(x,y)
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data = pd.read_csv("/home/virani/Documents/Data_LR.csv") # Import data from csv file
data.head() 

plt.scatter(data['cgpa'],data['package(Mn)']) # we can predict the y(package) from inputing x(cgpa)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data = pd.read_csv("/home/virani/Documents/Data_LR.csv") # Import data from csv file
data.head() 

x = data.iloc[:,0:1] # Separate column this is 1st column
y = data.iloc[:,-1]  # Indexing with -1 will choose last column

from sklearn.model_selection import train_test_split # we want to split our data in to train set and test set

# data divide into test size 0.2 means 20% test data and 80% train data
# random_state=2 means when we use this code as integer 2 then same randomization follows every time
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2) 

from sklearn.linear_model import LinearRegression

lr = LinearRegression() # made object
lr.fit(x_train,y_train) # This attribute .fit() will train model means it fine the best fitted line 

x_test.iloc[0]

# we can predict the y(package) from inputing x(cgpa), reshape() uses to change the shape of array
lr.predict(x_test.iloc[0].values.reshape(1,1)) 

plt.scatter(data['cgpa'],data['package(Mn)'])
plt.plot(x_train,lr.predict(x_train),color='red') # draw line with plt.plot((x1,y1),(x2,y2))
plt.xlabel('cgpa')
plt.ylabel('package(Mn)')

m = lr.coef_    # This attribute .coef_ will give us slope of line

b = lr.intercept_   #   This attribute .intercept_ will give us intercept of line
# Out:
# /home/virani/dev_ws/.venv/lib/python3.10/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt

m = 2.5          # Slope
b = 1.0          # Intercept
n = 10          # Number of data points
noise_level = 20  # Noise level (adjustable)

# Generate x-values (independent variable)
x = np.random.rand(n) * 100  # Random x values between 0 and 100
x_ = x.reshape(10,1)
# Calculate y-values based on the linear relationship with added noise we add noice to make more real data
y = m * x + b + np.random.randn(n) * noise_level  # y = mx + b + noise, w/o noise it will be line

plt.scatter(x_,y)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_,y)
m = print(reg.coef_)
# Out:
# [2.78281138]

# %%
plt.scatter(x,y)
plt.plot(x,reg.predict(x.reshape(10,1)),color='red')

# %%
# assume b=0
b = 0
y_pred = ((20 * x_)+b)

plt.scatter(x,y)
plt.plot(x,reg.predict(x_), color = 'green', label='perfect')
plt.plot(x,y_pred,color = 'grey')
plt.legend()
plt.show()

# %%
b = 0 
m = 2.41
lr = 0.1

mse_slope = -2 * np.sum(y - m*x_.ravel() - b)
mse_slope
b_new = b - (lr)*mse_slope
b = b_new
y_pred = m*x_.ravel() + b
print(b)
plt.scatter(x,y)
plt.plot(x,reg.predict(x_), color = 'green', label='perfect')
plt.plot(x,y_pred,color = 'grey')
plt.legend()
plt.show()
# Out:
# 20.97053626909655

# %%
epoch = 1000
b = -100
m = 2.41
lr = 0.01
class rutvik:
    def __init__(self):
        self.b = 0
        self.m = 2.41
        self.lr = 0.01
        self.epoch = 1000

    def fit(self, x, y):
    
        for i in range(self.epoch):
            mse_slope = -2 * np.sum(y - self.m*x_.ravel() - self.b)
        
            self.b = self.b - (self.lr * mse_slope)
    
            y_pred = m*x_ + self.b

            plt.plot(x,y_pred)
        plt.scatter(x,y)

# %%
rv = rutvik()

# %%
rv.fit(x,y)
